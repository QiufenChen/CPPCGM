# %%
import re
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from transformers import AdamW
import random
import pandas as pd
import numpy as np
import warnings
import torch
from transformers import BertTokenizer, BertLMHeadModel, AdamW, BertForSequenceClassification

# %%
def random_replace_residue(sequence):
    """
    purpose: randomly replace 50% of residues on the target sequence
    :param sequence: target sequence
    :return: new sequence with spaces
    """
    sequence_list = list(sequence)
    replace_indices = random.sample(range(len(sequence_list)), int(0.5 * len(sequence_list)))
    for index in replace_indices:
        sequence_list[index] = random.choice(['A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L', 
                                              'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'W', 'Y'])
    new_sequence = ' '.join(sequence_list)
    return new_sequence


def random_mask_sequence(sequence):
    """
    purpose: mask off 50% of the residues on the target sequence
    :param sequence: target sequence
    :return: new sequence with spaces
    """
    masked_sequence = ''
    mask_positions = []
    for i, aa in enumerate(sequence):
        if random.uniform(0, 1) < 0.5:
            masked_sequence += ' [MASK]'
            mask_positions.append(i)
        else:
            masked_sequence += ' ' + aa
    return masked_sequence


def random_generate_sequence(sequence):
    """
    purpose: randomly generate a sequence as long as the target sequence
    :param sequence: target sequence
    :return: newly generate sequence with spaces
    """
    amino_acids = 'ACDEFGHIKLMNPQRSTVWY'
    new_sequence = ' '.join([random.choice(amino_acids) for _ in range(len(sequence))])
    return new_sequence


class Generator(nn.Module):
    """ Define Generator """
    def __init__(self):
        super().__init__()
        self.model = BertLMHeadModel.from_pretrained(model_name, return_dict=False).cuda()
    
    def forward(self, input_ids, attention_mask):
        output = self.model(input_ids=input_ids, attention_mask=attention_mask)
        output_ids = torch.argmax(output[0], -1)
        return output_ids, output


class SequenceDataset(Dataset):
    """Create SequenceDataset Loader"""
    def __init__(self, sequences):
        self.sequences = sequences

    def __len__(self):
        return len(self.sequences)

    def __getitem__(self, index):
        real_seq = self.sequences[index]
        fake_seq = random_replace_residue(real_seq)

        real_seq = " ".join("".join(real_seq.split()))
        real_seq = re.sub(r"[UZOB]", "X", real_seq)
        real_seq_ids = tokenizer(real_seq, truncation=True, padding='max_length', max_length=70)
        real_sample = {key: torch.tensor(val) for key, val in real_seq_ids .items()}
        real_data = real_sample['input_ids']
        real_attention_mask = (real_sample['attention_mask'])

        fake_seq = re.sub(r"[UZOB]", "X", fake_seq)
        fake_seq_ids = tokenizer(fake_seq, truncation=True, padding='max_length', max_length=70)
        fake_sample = {key: torch.tensor(val) for key, val in fake_seq_ids.items()}
        fake_data = fake_sample['input_ids']
        fake_attention_mask = (fake_sample['attention_mask'])
        return (real_data, fake_data, fake_attention_mask)

# %%
model_name = "../Rostlab/prot_bert_bfd"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
tokenizer = BertTokenizer.from_pretrained(model_name)

# Load dataset and create Dataloader
file = '../dataset/CPPCase-2.csv'
seqs = [item for item in pd.read_csv(file)['Sequence'].values]
batch_size = 9
dataset = SequenceDataset(seqs)
dataloader = DataLoader(dataset=dataset, batch_size=batch_size, shuffle=False)

model = Generator()
model.load_state_dict(torch.load('/home/qfchen/CPPCGM/CPPGenerator/model/replace_generator.pt'))

model.eval()
generated_sequences = []
with torch.no_grad(): 
    for i, data in enumerate(dataloader):
        gene_data, gene_logits = model(data[1].to(device), data[2].to(device))
        decoded_seqs = tokenizer.batch_decode(gene_data, skip_special_tokens=True)
        generated_sequences.extend(decoded_seqs)
# Out:
# If you want to use `BertLMHeadModel` as a standalone, add `is_decoder=True.`
# /tmp/ipykernel_597683/13701891.py:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('/home/qfchen/CPPCGM/CPPGenerator/model/replace_generator.pt'))

# %%
for i, seq in enumerate(generated_sequences):
    print(f"Generated peptide {i+1}: {seq.replace(' ', '')}")
# Out:
# Generated peptide 1: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRPWWLKWLKKRRRRRRRRPWRLLKLLKWL
# Generated peptide 2: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHYFHKKHHKHAAAAAAAFYFAAAHHKFHK
# Generated peptide 3: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKKNKIKKIKKKXXXXXKKKNXKKKIKKKK
# Generated peptide 4: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRKRWRRWRRGGGGGGGGRRGGRRRRRRWR
# Generated peptide 5: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYIIWVDLIILIIRXRRRAIARRDVIIIIID

# %%
generated_sequences = [peptide.replace(' ', '') for peptide in generated_sequences]
start_len = 8

all_sequences = []
for peptide in generated_sequences:
    item = 0
    for length in range(start_len, len(peptide) + 1): 
        sequence = peptide[:length]
        if sequence not in seqs:
            all_sequences.append(sequence)
        print(f"Generated peptide {item + 1}: {sequence}")
        item += 1


df = pd.DataFrame(all_sequences, columns=["Peptide"])
df.to_csv('results/replace_generated_peptides_1.csv', index=False)
# Out:
# Generated peptide 1: RRRPWWLK
# Generated peptide 2: RRRPWWLKK
# Generated peptide 3: RRRPWWLKKL
# Generated peptide 4: RRRPWWLKKLK
# Generated peptide 5: RRRPWWLKKLKK
# Generated peptide 6: RRRPWWLKKLKKL
# Generated peptide 7: RRRPWWLKKLKKLL
# Generated peptide 8: RRRPWWLKKLKKLLK
# Generated peptide 9: RRRPWWLKKLKKLLKW
# Generated peptide 10: RRRPWWLKKLKKLLKWL
# Generated peptide 11: RRRPWWLKKLKKLLKWLL
# Generated peptide 12: RRRPWWLKKLKKLLKWLLK
# Generated peptide 13: RRRPWWLKKLKKLLKWLLKW
# Generated peptide 14: RRRPWWLKKLKKLLKWLLKWL
# Generated peptide 15: RRRPWWLKKLKKLLKWLLKWLK
# Generated peptide 16: RRRPWWLKKLKKLLKWLLKWLKW
# Generated peptide 17: RRRPWWLKKLKKLLKWLLKWLKWL
# Generated peptide 18: RRRPWWLKKLKKLLKWLLKWLKWLL
# Generated peptide 19: RRRPWWLKKLKKLLKWLLKWLKWLLK
# Generated peptide 20: RRRPWWLKKLKKLLKWLLKWLKWLLKL
# Generated peptide 21: RRRPWWLKKLKKLLKWLLKWLKWLLKLL
# Generated peptide 22: RRRPWWLKKLKKLLKWLLKWLKWLLKLLW
# Generated peptide 23: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWL
# Generated peptide 24: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLR
# Generated peptide 25: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRP
# Generated peptide 26: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPW
# Generated peptide 27: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWW
# Generated peptide 28: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWL
# Generated peptide 29: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLK
# Generated peptide 30: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKL
# Generated peptide 31: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLL
# Generated peptide 32: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLK
# Generated peptide 33: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKW
# Generated peptide 34: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWR
# Generated peptide 35: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRR
# Generated peptide 36: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRP
# Generated peptide 37: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRPW
# Generated peptide 38: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRPWW
# Generated peptide 39: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRPWWL
# Generated peptide 40: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRPWWLK
# Generated peptide 41: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRPWWLKW
# Generated peptide 42: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRPWWLKWL
# Generated peptide 43: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRPWWLKWLK
# Generated peptide 44: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRPWWLKWLKK
# Generated peptide 45: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRPWWLKWLKKR
# Generated peptide 46: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRPWWLKWLKKRR
# Generated peptide 47: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRPWWLKWLKKRRR
# Generated peptide 48: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRPWWLKWLKKRRRR
# Generated peptide 49: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRPWWLKWLKKRRRRR
# Generated peptide 50: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRPWWLKWLKKRRRRRR
# Generated peptide 51: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRPWWLKWLKKRRRRRRR
# Generated peptide 52: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRPWWLKWLKKRRRRRRRR
# Generated peptide 53: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRPWWLKWLKKRRRRRRRRP
# Generated peptide 54: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRPWWLKWLKKRRRRRRRRPW
# Generated peptide 55: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRPWWLKWLKKRRRRRRRRPWR
# Generated peptide 56: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRPWWLKWLKKRRRRRRRRPWRL
# Generated peptide 57: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRPWWLKWLKKRRRRRRRRPWRLL
# Generated peptide 58: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRPWWLKWLKKRRRRRRRRPWRLLK
# Generated peptide 59: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRPWWLKWLKKRRRRRRRRPWRLLKL
# Generated peptide 60: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRPWWLKWLKKRRRRRRRRPWRLLKLL
# Generated peptide 61: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRPWWLKWLKKRRRRRRRRPWRLLKLLK
# Generated peptide 62: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRPWWLKWLKKRRRRRRRRPWRLLKLLKW
# Generated peptide 63: RRRPWWLKKLKKLLKWLLKWLKWLLKLLWLRPWWLKLLKWRRPWWLKWLKKRRRRRRRRPWRLLKLLKWL
# Generated peptide 1: AFWYFHKK
# Generated peptide 2: AFWYFHKKF
# Generated peptide 3: AFWYFHKKFH
# Generated peptide 4: AFWYFHKKFHK
# Generated peptide 5: AFWYFHKKFHKK
# Generated peptide 6: AFWYFHKKFHKKF
# Generated peptide 7: AFWYFHKKFHKKFK
# Generated peptide 8: AFWYFHKKFHKKFKY
# Generated peptide 9: AFWYFHKKFHKKFKYF
# Generated peptide 10: AFWYFHKKFHKKFKYFH
# Generated peptide 11: AFWYFHKKFHKKFKYFHY
# Generated peptide 12: AFWYFHKKFHKKFKYFHYK
# Generated peptide 13: AFWYFHKKFHKKFKYFHYKH
# Generated peptide 14: AFWYFHKKFHKKFKYFHYKHH
# Generated peptide 15: AFWYFHKKFHKKFKYFHYKHHY
# Generated peptide 16: AFWYFHKKFHKKFKYFHYKHHYH
# Generated peptide 17: AFWYFHKKFHKKFKYFHYKHHYHH
# Generated peptide 18: AFWYFHKKFHKKFKYFHYKHHYHHK
# Generated peptide 19: AFWYFHKKFHKKFKYFHYKHHYHHKF
# Generated peptide 20: AFWYFHKKFHKKFKYFHYKHHYHHKFW
# Generated peptide 21: AFWYFHKKFHKKFKYFHYKHHYHHKFWY
# Generated peptide 22: AFWYFHKKFHKKFKYFHYKHHYHHKFWYF
# Generated peptide 23: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFH
# Generated peptide 24: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHH
# Generated peptide 25: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHY
# Generated peptide 26: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYF
# Generated peptide 27: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFH
# Generated peptide 28: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHK
# Generated peptide 29: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKK
# Generated peptide 30: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKF
# Generated peptide 31: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFH
# Generated peptide 32: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHY
# Generated peptide 33: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYF
# Generated peptide 34: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFF
# Generated peptide 35: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFH
# Generated peptide 36: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHY
# Generated peptide 37: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHYF
# Generated peptide 38: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHYFH
# Generated peptide 39: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHYFHK
# Generated peptide 40: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHYFHKK
# Generated peptide 41: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHYFHKKH
# Generated peptide 42: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHYFHKKHH
# Generated peptide 43: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHYFHKKHHK
# Generated peptide 44: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHYFHKKHHKH
# Generated peptide 45: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHYFHKKHHKHA
# Generated peptide 46: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHYFHKKHHKHAA
# Generated peptide 47: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHYFHKKHHKHAAA
# Generated peptide 48: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHYFHKKHHKHAAAA
# Generated peptide 49: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHYFHKKHHKHAAAAA
# Generated peptide 50: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHYFHKKHHKHAAAAAA
# Generated peptide 51: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHYFHKKHHKHAAAAAAA
# Generated peptide 52: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHYFHKKHHKHAAAAAAAF
# Generated peptide 53: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHYFHKKHHKHAAAAAAAFY
# Generated peptide 54: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHYFHKKHHKHAAAAAAAFYF
# Generated peptide 55: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHYFHKKHHKHAAAAAAAFYFA
# Generated peptide 56: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHYFHKKHHKHAAAAAAAFYFAA
# Generated peptide 57: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHYFHKKHHKHAAAAAAAFYFAAA
# Generated peptide 58: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHYFHKKHHKHAAAAAAAFYFAAAH
# Generated peptide 59: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHYFHKKHHKHAAAAAAAFYFAAAHH
# Generated peptide 60: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHYFHKKHHKHAAAAAAAFYFAAAHHK
# Generated peptide 61: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHYFHKKHHKHAAAAAAAFYFAAAHHKF
# Generated peptide 62: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHYFHKKHHKHAAAAAAAFYFAAAHHKFH
# Generated peptide 63: AFWYFHKKFHKKFKYFHYKHHYHHKFWYFHHYFHKKFHYFFHYFHKKHHKHAAAAAAAFYFAAAHHKFHK
# Generated peptide 1: XMKKNKIK
# Generated peptide 2: XMKKNKIKK
# Generated peptide 3: XMKKNKIKKK
# Generated peptide 4: XMKKNKIKKKK
# Generated peptide 5: XMKKNKIKKKKK
# Generated peptide 6: XMKKNKIKKKKKK
# Generated peptide 7: XMKKNKIKKKKKKK
# Generated peptide 8: XMKKNKIKKKKKKKK
# Generated peptide 9: XMKKNKIKKKKKKKKK
# Generated peptide 10: XMKKNKIKKKKKKKKKK
# Generated peptide 11: XMKKNKIKKKKKKKKKKK
# Generated peptide 12: XMKKNKIKKKKKKKKKKKK
# Generated peptide 13: XMKKNKIKKKKKKKKKKKKK
# Generated peptide 14: XMKKNKIKKKKKKKKKKKKKK
# Generated peptide 15: XMKKNKIKKKKKKKKKKKKKKK
# Generated peptide 16: XMKKNKIKKKKKKKKKKKKKKKK
# Generated peptide 17: XMKKNKIKKKKKKKKKKKKKKKKI
# Generated peptide 18: XMKKNKIKKKKKKKKKKKKKKKKII
# Generated peptide 19: XMKKNKIKKKKKKKKKKKKKKKKIIK
# Generated peptide 20: XMKKNKIKKKKKKKKKKKKKKKKIIKK
# Generated peptide 21: XMKKNKIKKKKKKKKKKKKKKKKIIKKK
# Generated peptide 22: XMKKNKIKKKKKKKKKKKKKKKKIIKKKK
# Generated peptide 23: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKK
# Generated peptide 24: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKK
# Generated peptide 25: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKK
# Generated peptide 26: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKN
# Generated peptide 27: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNK
# Generated peptide 28: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKI
# Generated peptide 29: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIK
# Generated peptide 30: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKK
# Generated peptide 31: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKK
# Generated peptide 32: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKK
# Generated peptide 33: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKK
# Generated peptide 34: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKK
# Generated peptide 35: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKK
# Generated peptide 36: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKK
# Generated peptide 37: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKKN
# Generated peptide 38: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKKNK
# Generated peptide 39: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKKNKI
# Generated peptide 40: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKKNKIK
# Generated peptide 41: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKKNKIKK
# Generated peptide 42: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKKNKIKKI
# Generated peptide 43: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKKNKIKKIK
# Generated peptide 44: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKKNKIKKIKK
# Generated peptide 45: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKKNKIKKIKKK
# Generated peptide 46: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKKNKIKKIKKKX
# Generated peptide 47: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKKNKIKKIKKKXX
# Generated peptide 48: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKKNKIKKIKKKXXX
# Generated peptide 49: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKKNKIKKIKKKXXXX
# Generated peptide 50: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKKNKIKKIKKKXXXXX
# Generated peptide 51: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKKNKIKKIKKKXXXXXK
# Generated peptide 52: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKKNKIKKIKKKXXXXXKK
# Generated peptide 53: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKKNKIKKIKKKXXXXXKKK
# Generated peptide 54: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKKNKIKKIKKKXXXXXKKKN
# Generated peptide 55: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKKNKIKKIKKKXXXXXKKKNX
# Generated peptide 56: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKKNKIKKIKKKXXXXXKKKNXK
# Generated peptide 57: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKKNKIKKIKKKXXXXXKKKNXKK
# Generated peptide 58: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKKNKIKKIKKKXXXXXKKKNXKKK
# Generated peptide 59: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKKNKIKKIKKKXXXXXKKKNXKKKI
# Generated peptide 60: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKKNKIKKIKKKXXXXXKKKNXKKKIK
# Generated peptide 61: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKKNKIKKIKKKXXXXXKKKNXKKKIKK
# Generated peptide 62: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKKNKIKKIKKKXXXXXKKKNXKKKIKKK
# Generated peptide 63: XMKKNKIKKKKKKKKKKKKKKKKIIKKKKKKKNKIKKKKKKKKNKIKKIKKKXXXXXKKKNXKKKIKKKK
# Generated peptide 1: GIRKRWRR
# Generated peptide 2: GIRKRWRRR
# Generated peptide 3: GIRKRWRRRR
# Generated peptide 4: GIRKRWRRRRR
# Generated peptide 5: GIRKRWRRRRRR
# Generated peptide 6: GIRKRWRRRRRRR
# Generated peptide 7: GIRKRWRRRRRRRR
# Generated peptide 8: GIRKRWRRRRRRRRR
# Generated peptide 9: GIRKRWRRRRRRRRRR
# Generated peptide 10: GIRKRWRRRRRRRRRRR
# Generated peptide 11: GIRKRWRRRRRRRRRRRK
# Generated peptide 12: GIRKRWRRRRRRRRRRRKR
# Generated peptide 13: GIRKRWRRRRRRRRRRRKRW
# Generated peptide 14: GIRKRWRRRRRRRRRRRKRWR
# Generated peptide 15: GIRKRWRRRRRRRRRRRKRWRR
# Generated peptide 16: GIRKRWRRRRRRRRRRRKRWRRW
# Generated peptide 17: GIRKRWRRRRRRRRRRRKRWRRWR
# Generated peptide 18: GIRKRWRRRRRRRRRRRKRWRRWRR
# Generated peptide 19: GIRKRWRRRRRRRRRRRKRWRRWRRI
# Generated peptide 20: GIRKRWRRRRRRRRRRRKRWRRWRRIR
# Generated peptide 21: GIRKRWRRRRRRRRRRRKRWRRWRRIRR
# Generated peptide 22: GIRKRWRRRRRRRRRRRKRWRRWRRIRRR
# Generated peptide 23: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRR
# Generated peptide 24: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRR
# Generated peptide 25: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRK
# Generated peptide 26: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKR
# Generated peptide 27: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRW
# Generated peptide 28: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWR
# Generated peptide 29: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRR
# Generated peptide 30: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRR
# Generated peptide 31: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRR
# Generated peptide 32: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRR
# Generated peptide 33: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRR
# Generated peptide 34: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRI
# Generated peptide 35: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIR
# Generated peptide 36: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRK
# Generated peptide 37: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRKR
# Generated peptide 38: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRKRW
# Generated peptide 39: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRKRWR
# Generated peptide 40: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRKRWRR
# Generated peptide 41: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRKRWRRW
# Generated peptide 42: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRKRWRRWR
# Generated peptide 43: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRKRWRRWRR
# Generated peptide 44: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRKRWRRWRRG
# Generated peptide 45: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRKRWRRWRRGG
# Generated peptide 46: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRKRWRRWRRGGG
# Generated peptide 47: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRKRWRRWRRGGGG
# Generated peptide 48: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRKRWRRWRRGGGGG
# Generated peptide 49: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRKRWRRWRRGGGGGG
# Generated peptide 50: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRKRWRRWRRGGGGGGG
# Generated peptide 51: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRKRWRRWRRGGGGGGGG
# Generated peptide 52: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRKRWRRWRRGGGGGGGGR
# Generated peptide 53: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRKRWRRWRRGGGGGGGGRR
# Generated peptide 54: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRKRWRRWRRGGGGGGGGRRG
# Generated peptide 55: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRKRWRRWRRGGGGGGGGRRGG
# Generated peptide 56: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRKRWRRWRRGGGGGGGGRRGGR
# Generated peptide 57: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRKRWRRWRRGGGGGGGGRRGGRR
# Generated peptide 58: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRKRWRRWRRGGGGGGGGRRGGRRR
# Generated peptide 59: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRKRWRRWRRGGGGGGGGRRGGRRRR
# Generated peptide 60: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRKRWRRWRRGGGGGGGGRRGGRRRRR
# Generated peptide 61: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRKRWRRWRRGGGGGGGGRRGGRRRRRR
# Generated peptide 62: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRKRWRRWRRGGGGGGGGRRGGRRRRRRW
# Generated peptide 63: GIRKRWRRRRRRRRRRRKRWRRWRRIRRRRRKRWRRRRRRIRKRWRRWRRGGGGGGGGRRGGRRRRRRWR
# Generated peptide 1: RYIAWVDL
# Generated peptide 2: RYIAWVDLI
# Generated peptide 3: RYIAWVDLIQ
# Generated peptide 4: RYIAWVDLIQI
# Generated peptide 5: RYIAWVDLIQII
# Generated peptide 6: RYIAWVDLIQIII
# Generated peptide 7: RYIAWVDLIQIIII
# Generated peptide 8: RYIAWVDLIQIIIIV
# Generated peptide 9: RYIAWVDLIQIIIIVW
# Generated peptide 10: RYIAWVDLIQIIIIVWI
# Generated peptide 11: RYIAWVDLIQIIIIVWIV
# Generated peptide 12: RYIAWVDLIQIIIIVWIVW
# Generated peptide 13: RYIAWVDLIQIIIIVWIVWV
# Generated peptide 14: RYIAWVDLIQIIIIVWIVWVD
# Generated peptide 15: RYIAWVDLIQIIIIVWIVWVDL
# Generated peptide 16: RYIAWVDLIQIIIIVWIVWVDLI
# Generated peptide 17: RYIAWVDLIQIIIIVWIVWVDLII
# Generated peptide 18: RYIAWVDLIQIIIIVWIVWVDLIID
# Generated peptide 19: RYIAWVDLIQIIIIVWIVWVDLIIDW
# Generated peptide 20: RYIAWVDLIQIIIIVWIVWVDLIIDWI
# Generated peptide 21: RYIAWVDLIQIIIIVWIVWVDLIIDWID
# Generated peptide 22: RYIAWVDLIQIIIIVWIVWVDLIIDWIDL
# Generated peptide 23: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLV
# Generated peptide 24: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVI
# Generated peptide 25: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIV
# Generated peptide 26: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVW
# Generated peptide 27: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWV
# Generated peptide 28: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVD
# Generated peptide 29: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDL
# Generated peptide 30: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLI
# Generated peptide 31: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLII
# Generated peptide 32: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIV
# Generated peptide 33: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVI
# Generated peptide 34: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIY
# Generated peptide 35: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYI
# Generated peptide 36: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYII
# Generated peptide 37: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYIIW
# Generated peptide 38: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYIIWV
# Generated peptide 39: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYIIWVD
# Generated peptide 40: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYIIWVDL
# Generated peptide 41: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYIIWVDLI
# Generated peptide 42: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYIIWVDLII
# Generated peptide 43: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYIIWVDLIIL
# Generated peptide 44: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYIIWVDLIILI
# Generated peptide 45: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYIIWVDLIILII
# Generated peptide 46: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYIIWVDLIILIIR
# Generated peptide 47: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYIIWVDLIILIIRX
# Generated peptide 48: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYIIWVDLIILIIRXR
# Generated peptide 49: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYIIWVDLIILIIRXRR
# Generated peptide 50: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYIIWVDLIILIIRXRRR
# Generated peptide 51: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYIIWVDLIILIIRXRRRA
# Generated peptide 52: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYIIWVDLIILIIRXRRRAI
# Generated peptide 53: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYIIWVDLIILIIRXRRRAIA
# Generated peptide 54: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYIIWVDLIILIIRXRRRAIAR
# Generated peptide 55: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYIIWVDLIILIIRXRRRAIARR
# Generated peptide 56: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYIIWVDLIILIIRXRRRAIARRD
# Generated peptide 57: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYIIWVDLIILIIRXRRRAIARRDV
# Generated peptide 58: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYIIWVDLIILIIRXRRRAIARRDVI
# Generated peptide 59: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYIIWVDLIILIIRXRRRAIARRDVII
# Generated peptide 60: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYIIWVDLIILIIRXRRRAIARRDVIII
# Generated peptide 61: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYIIWVDLIILIIRXRRRAIARRDVIIII
# Generated peptide 62: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYIIWVDLIILIIRXRRRAIARRDVIIIII
# Generated peptide 63: RYIAWVDLIQIIIIVWIVWVDLIIDWIDLVIVWVDLIIVIYIIWVDLIILIIRXRRRAIARRDVIIIIID
