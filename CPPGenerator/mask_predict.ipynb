# %%
import re
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from transformers import AdamW
import random
import pandas as pd
import numpy as np
import warnings
import torch
from transformers import BertTokenizer, BertLMHeadModel, AdamW, BertForSequenceClassification

# %%
def random_replace_residue(sequence):
    """
    purpose: randomly replace 50% of residues on the target sequence
    :param sequence: target sequence
    :return: new sequence with spaces
    """
    sequence_list = list(sequence)
    replace_indices = random.sample(range(len(sequence_list)), int(0.5 * len(sequence_list)))
    for index in replace_indices:
        sequence_list[index] = random.choice(['A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L', 
                                              'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'W', 'Y'])
    new_sequence = ' '.join(sequence_list)
    return new_sequence


def random_mask_sequence(sequence):
    """
    purpose: mask off 50% of the residues on the target sequence
    :param sequence: target sequence
    :return: new sequence with spaces
    """
    masked_sequence = ''
    mask_positions = []
    for i, aa in enumerate(sequence):
        if random.uniform(0, 1) < 0.5:
            masked_sequence += ' [MASK]'
            mask_positions.append(i)
        else:
            masked_sequence += ' ' + aa
    return masked_sequence


def random_generate_sequence(sequence):
    """
    purpose: randomly generate a sequence as long as the target sequence
    :param sequence: target sequence
    :return: newly generate sequence with spaces
    """
    amino_acids = 'ACDEFGHIKLMNPQRSTVWY'
    new_sequence = ' '.join([random.choice(amino_acids) for _ in range(len(sequence))])
    return new_sequence


class Generator(nn.Module):
    """ Define Generator """
    def __init__(self):
        super().__init__()
        self.model = BertLMHeadModel.from_pretrained(model_name, return_dict=False).cuda()
    
    def forward(self, input_ids, attention_mask):
        output = self.model(input_ids=input_ids, attention_mask=attention_mask)
        output_ids = torch.argmax(output[0], -1)
        return output_ids, output


class SequenceDataset(Dataset):
    """Create SequenceDataset Loader"""
    def __init__(self, sequences):
        self.sequences = sequences

    def __len__(self):
        return len(self.sequences)

    def __getitem__(self, index):
        real_seq = self.sequences[index]
        fake_seq = random_mask_sequence(real_seq)

        real_seq = " ".join("".join(real_seq.split()))
        real_seq = re.sub(r"[UZOB]", "X", real_seq)
        real_seq_ids = tokenizer(real_seq, truncation=True, padding='max_length', max_length=70)
        real_sample = {key: torch.tensor(val) for key, val in real_seq_ids .items()}
        real_data = real_sample['input_ids']
        real_attention_mask = (real_sample['attention_mask'])

        fake_seq = re.sub(r"[UZOB]", "X", fake_seq)
        fake_seq_ids = tokenizer(fake_seq, truncation=True, padding='max_length', max_length=70)
        fake_sample = {key: torch.tensor(val) for key, val in fake_seq_ids.items()}
        fake_data = fake_sample['input_ids']
        fake_attention_mask = (fake_sample['attention_mask'])
        return (real_data, fake_data, fake_attention_mask)

# %%
model_name = "../Rostlab/prot_bert_bfd"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
tokenizer = BertTokenizer.from_pretrained(model_name)

# Load dataset and create Dataloader
file = '../dataset/CPPCase-2.csv'
seqs = [item for item in pd.read_csv(file)['Sequence'].values]
batch_size = 9
dataset = SequenceDataset(seqs)
dataloader = DataLoader(dataset=dataset, batch_size=batch_size, shuffle=False)

model = Generator()
model.load_state_dict(torch.load('/home/qfchen/CPPCGM/CPPGenerator/model/mask_generator.pt'))


model.eval()
generated_sequences = []
with torch.no_grad(): 
    for i, data in enumerate(dataloader):
        gene_data, gene_logits = model(data[1].to(device), data[2].to(device))
        decoded_seqs = tokenizer.batch_decode(gene_data, skip_special_tokens=True)
        generated_sequences.extend(decoded_seqs)
# Out:
# If you want to use `BertLMHeadModel` as a standalone, add `is_decoder=True.`
# /tmp/ipykernel_597804/655186783.py:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('/home/qfchen/CPPCGM/CPPGenerator/model/mask_generator.pt'))

# %%
for i, seq in enumerate(generated_sequences):
    print(f"Generated peptide {i+1}: {seq.replace(' ', '')}")
# Out:
# Generated peptide 1: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWMKWKKWKKKKXXXXXMWWXXKKKKKKWK
# Generated peptide 2: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQKFQKFQKKSAAAAAAAQKAAAAFAAFQQ
# Generated peptide 3: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKKKKKKKKKKAAAAAAKKKKAKKKKKKAK
# Generated peptide 4: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRKRRRRRRRRRR
# Generated peptide 5: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAAYRRLLRLLLALAAAAAALARALRLLAR

# %%
generated_sequences = [peptide.replace(' ', '') for peptide in generated_sequences]
start_len = 8

all_sequences = []
for peptide in generated_sequences:
    item = 0
    for length in range(start_len, len(peptide) + 1): 
        sequence = peptide[:length]
        if sequence not in seqs:
            all_sequences.append(sequence)
        print(f"Generated peptide {item + 1}: {sequence}")
        item += 1


df = pd.DataFrame(all_sequences, columns=["Peptide"])
df.to_csv('results/mask_generated_peptides_1.csv', index=False)
# Out:
# Generated peptide 1: XKWMKWKK
# Generated peptide 2: XKWMKWKKW
# Generated peptide 3: XKWMKWKKWK
# Generated peptide 4: XKWMKWKKWKK
# Generated peptide 5: XKWMKWKKWKKK
# Generated peptide 6: XKWMKWKKWKKKW
# Generated peptide 7: XKWMKWKKWKKKWW
# Generated peptide 8: XKWMKWKKWKKKWWK
# Generated peptide 9: XKWMKWKKWKKKWWKK
# Generated peptide 10: XKWMKWKKWKKKWWKKW
# Generated peptide 11: XKWMKWKKWKKKWWKKWK
# Generated peptide 12: XKWMKWKKWKKKWWKKWKK
# Generated peptide 13: XKWMKWKKWKKKWWKKWKKW
# Generated peptide 14: XKWMKWKKWKKKWWKKWKKWK
# Generated peptide 15: XKWMKWKKWKKKWWKKWKKWKK
# Generated peptide 16: XKWMKWKKWKKKWWKKWKKWKKK
# Generated peptide 17: XKWMKWKKWKKKWWKKWKKWKKKK
# Generated peptide 18: XKWMKWKKWKKKWWKKWKKWKKKKK
# Generated peptide 19: XKWMKWKKWKKKWWKKWKKWKKKKKK
# Generated peptide 20: XKWMKWKKWKKKWWKKWKKWKKKKKKW
# Generated peptide 21: XKWMKWKKWKKKWWKKWKKWKKKKKKWM
# Generated peptide 22: XKWMKWKKWKKKWWKKWKKWKKKKKKWMK
# Generated peptide 23: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKW
# Generated peptide 24: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWK
# Generated peptide 25: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKM
# Generated peptide 26: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMK
# Generated peptide 27: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKW
# Generated peptide 28: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWK
# Generated peptide 29: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKK
# Generated peptide 30: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKK
# Generated peptide 31: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKK
# Generated peptide 32: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKK
# Generated peptide 33: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKK
# Generated peptide 34: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKK
# Generated peptide 35: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKW
# Generated peptide 36: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWM
# Generated peptide 37: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWMK
# Generated peptide 38: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWMKW
# Generated peptide 39: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWMKWK
# Generated peptide 40: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWMKWKK
# Generated peptide 41: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWMKWKKW
# Generated peptide 42: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWMKWKKWK
# Generated peptide 43: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWMKWKKWKK
# Generated peptide 44: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWMKWKKWKKK
# Generated peptide 45: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWMKWKKWKKKK
# Generated peptide 46: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWMKWKKWKKKKX
# Generated peptide 47: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWMKWKKWKKKKXX
# Generated peptide 48: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWMKWKKWKKKKXXX
# Generated peptide 49: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWMKWKKWKKKKXXXX
# Generated peptide 50: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWMKWKKWKKKKXXXXX
# Generated peptide 51: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWMKWKKWKKKKXXXXXM
# Generated peptide 52: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWMKWKKWKKKKXXXXXMW
# Generated peptide 53: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWMKWKKWKKKKXXXXXMWW
# Generated peptide 54: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWMKWKKWKKKKXXXXXMWWX
# Generated peptide 55: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWMKWKKWKKKKXXXXXMWWXX
# Generated peptide 56: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWMKWKKWKKKKXXXXXMWWXXK
# Generated peptide 57: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWMKWKKWKKKKXXXXXMWWXXKK
# Generated peptide 58: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWMKWKKWKKKKXXXXXMWWXXKKK
# Generated peptide 59: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWMKWKKWKKKKXXXXXMWWXXKKKK
# Generated peptide 60: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWMKWKKWKKKKXXXXXMWWXXKKKKK
# Generated peptide 61: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWMKWKKWKKKKXXXXXMWWXXKKKKKK
# Generated peptide 62: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWMKWKKWKKKKXXXXXMWWXXKKKKKKW
# Generated peptide 63: XKWMKWKKWKKKWWKKWKKWKKKKKKWMKWKMKWKKKKKKKWMKWKKWKKKKXXXXXMWWXXKKKKKKWK
# Generated peptide 1: AFQKFQKF
# Generated peptide 2: AFQKFQKFF
# Generated peptide 3: AFQKFQKFFQ
# Generated peptide 4: AFQKFQKFFQK
# Generated peptide 5: AFQKFQKFFQKF
# Generated peptide 6: AFQKFQKFFQKFQ
# Generated peptide 7: AFQKFQKFFQKFQK
# Generated peptide 8: AFQKFQKFFQKFQKK
# Generated peptide 9: AFQKFQKFFQKFQKKF
# Generated peptide 10: AFQKFQKFFQKFQKKFQ
# Generated peptide 11: AFQKFQKFFQKFQKKFQK
# Generated peptide 12: AFQKFQKFFQKFQKKFQKF
# Generated peptide 13: AFQKFQKFFQKFQKKFQKFQ
# Generated peptide 14: AFQKFQKFFQKFQKKFQKFQK
# Generated peptide 15: AFQKFQKFFQKFQKKFQKFQKK
# Generated peptide 16: AFQKFQKFFQKFQKKFQKFQKKF
# Generated peptide 17: AFQKFQKFFQKFQKKFQKFQKKFQ
# Generated peptide 18: AFQKFQKFFQKFQKKFQKFQKKFQK
# Generated peptide 19: AFQKFQKFFQKFQKKFQKFQKKFQKF
# Generated peptide 20: AFQKFQKFFQKFQKKFQKFQKKFQKFQ
# Generated peptide 21: AFQKFQKFFQKFQKKFQKFQKKFQKFQK
# Generated peptide 22: AFQKFQKFFQKFQKKFQKFQKKFQKFQKF
# Generated peptide 23: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFF
# Generated peptide 24: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQ
# Generated peptide 25: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQK
# Generated peptide 26: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKF
# Generated peptide 27: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQ
# Generated peptide 28: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQK
# Generated peptide 29: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKF
# Generated peptide 30: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQ
# Generated peptide 31: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQ
# Generated peptide 32: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQK
# Generated peptide 33: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKF
# Generated peptide 34: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFF
# Generated peptide 35: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQ
# Generated peptide 36: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQK
# Generated peptide 37: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQKF
# Generated peptide 38: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQKFQ
# Generated peptide 39: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQKFQK
# Generated peptide 40: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQKFQKF
# Generated peptide 41: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQKFQKFQ
# Generated peptide 42: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQKFQKFQK
# Generated peptide 43: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQKFQKFQKK
# Generated peptide 44: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQKFQKFQKKS
# Generated peptide 45: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQKFQKFQKKSA
# Generated peptide 46: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQKFQKFQKKSAA
# Generated peptide 47: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQKFQKFQKKSAAA
# Generated peptide 48: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQKFQKFQKKSAAAA
# Generated peptide 49: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQKFQKFQKKSAAAAA
# Generated peptide 50: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQKFQKFQKKSAAAAAA
# Generated peptide 51: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQKFQKFQKKSAAAAAAA
# Generated peptide 52: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQKFQKFQKKSAAAAAAAQ
# Generated peptide 53: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQKFQKFQKKSAAAAAAAQK
# Generated peptide 54: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQKFQKFQKKSAAAAAAAQKA
# Generated peptide 55: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQKFQKFQKKSAAAAAAAQKAA
# Generated peptide 56: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQKFQKFQKKSAAAAAAAQKAAA
# Generated peptide 57: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQKFQKFQKKSAAAAAAAQKAAAA
# Generated peptide 58: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQKFQKFQKKSAAAAAAAQKAAAAF
# Generated peptide 59: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQKFQKFQKKSAAAAAAAQKAAAAFA
# Generated peptide 60: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQKFQKFQKKSAAAAAAAQKAAAAFAA
# Generated peptide 61: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQKFQKFQKKSAAAAAAAQKAAAAFAAF
# Generated peptide 62: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQKFQKFQKKSAAAAAAAQKAAAAFAAFQ
# Generated peptide 63: AFQKFQKFFQKFQKKFQKFQKKFQKFQKFFQKFQKFQQKFFQKFQKFQKKSAAAAAAAQKAAAAFAAFQQ
# Generated peptide 1: ASKKKKKK
# Generated peptide 2: ASKKKKKKV
# Generated peptide 3: ASKKKKKKVK
# Generated peptide 4: ASKKKKKKVKK
# Generated peptide 5: ASKKKKKKVKKK
# Generated peptide 6: ASKKKKKKVKKKK
# Generated peptide 7: ASKKKKKKVKKKKK
# Generated peptide 8: ASKKKKKKVKKKKKK
# Generated peptide 9: ASKKKKKKVKKKKKKK
# Generated peptide 10: ASKKKKKKVKKKKKKKK
# Generated peptide 11: ASKKKKKKVKKKKKKKKK
# Generated peptide 12: ASKKKKKKVKKKKKKKKKK
# Generated peptide 13: ASKKKKKKVKKKKKKKKKKK
# Generated peptide 14: ASKKKKKKVKKKKKKKKKKKK
# Generated peptide 15: ASKKKKKKVKKKKKKKKKKKKK
# Generated peptide 16: ASKKKKKKVKKKKKKKKKKKKKK
# Generated peptide 17: ASKKKKKKVKKKKKKKKKKKKKKK
# Generated peptide 18: ASKKKKKKVKKKKKKKKKKKKKKKK
# Generated peptide 19: ASKKKKKKVKKKKKKKKKKKKKKKKK
# Generated peptide 20: ASKKKKKKVKKKKKKKKKKKKKKKKKK
# Generated peptide 21: ASKKKKKKVKKKKKKKKKKKKKKKKKKK
# Generated peptide 22: ASKKKKKKVKKKKKKKKKKKKKKKKKKKK
# Generated peptide 23: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKK
# Generated peptide 24: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKK
# Generated peptide 25: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKK
# Generated peptide 26: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKK
# Generated peptide 27: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKK
# Generated peptide 28: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKK
# Generated peptide 29: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKK
# Generated peptide 30: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKK
# Generated peptide 31: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKK
# Generated peptide 32: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKK
# Generated peptide 33: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKK
# Generated peptide 34: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKS
# Generated peptide 35: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSK
# Generated peptide 36: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKK
# Generated peptide 37: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKKK
# Generated peptide 38: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKKKK
# Generated peptide 39: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKKKKK
# Generated peptide 40: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKKKKKK
# Generated peptide 41: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKKKKKKK
# Generated peptide 42: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKKKKKKKK
# Generated peptide 43: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKKKKKKKKK
# Generated peptide 44: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKKKKKKKKKK
# Generated peptide 45: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKKKKKKKKKKA
# Generated peptide 46: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKKKKKKKKKKAA
# Generated peptide 47: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKKKKKKKKKKAAA
# Generated peptide 48: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKKKKKKKKKKAAAA
# Generated peptide 49: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKKKKKKKKKKAAAAA
# Generated peptide 50: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKKKKKKKKKKAAAAAA
# Generated peptide 51: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKKKKKKKKKKAAAAAAK
# Generated peptide 52: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKKKKKKKKKKAAAAAAKK
# Generated peptide 53: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKKKKKKKKKKAAAAAAKKK
# Generated peptide 54: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKKKKKKKKKKAAAAAAKKKK
# Generated peptide 55: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKKKKKKKKKKAAAAAAKKKKA
# Generated peptide 56: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKKKKKKKKKKAAAAAAKKKKAK
# Generated peptide 57: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKKKKKKKKKKAAAAAAKKKKAKK
# Generated peptide 58: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKKKKKKKKKKAAAAAAKKKKAKKK
# Generated peptide 59: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKKKKKKKKKKAAAAAAKKKKAKKKK
# Generated peptide 60: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKKKKKKKKKKAAAAAAKKKKAKKKKK
# Generated peptide 61: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKKKKKKKKKKAAAAAAKKKKAKKKKKK
# Generated peptide 62: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKKKKKKKKKKAAAAAAKKKKAKKKKKKA
# Generated peptide 63: ASKKKKKKVKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKSKKKKKKKKKKAAAAAAKKKKAKKKKKKAK
# Generated peptide 1: RKRRRRRR
# Generated peptide 2: RKRRRRRRR
# Generated peptide 3: RKRRRRRRRR
# Generated peptide 4: RKRRRRRRRRR
# Generated peptide 5: RKRRRRRRRRRR
# Generated peptide 6: RKRRRRRRRRRRR
# Generated peptide 7: RKRRRRRRRRRRRR
# Generated peptide 8: RKRRRRRRRRRRRRR
# Generated peptide 9: RKRRRRRRRRRRRRRR
# Generated peptide 10: RKRRRRRRRRRRRRRRR
# Generated peptide 11: RKRRRRRRRRRRRRRRRR
# Generated peptide 12: RKRRRRRRRRRRRRRRRRR
# Generated peptide 13: RKRRRRRRRRRRRRRRRRRR
# Generated peptide 14: RKRRRRRRRRRRRRRRRRRRR
# Generated peptide 15: RKRRRRRRRRRRRRRRRRRRRR
# Generated peptide 16: RKRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 17: RKRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 18: RKRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 19: RKRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 20: RKRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 21: RKRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 22: RKRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 23: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 24: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 25: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 26: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 27: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 28: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 29: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 30: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 31: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 32: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 33: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 34: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 35: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 36: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 37: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 38: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 39: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 40: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 41: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 42: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 43: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 44: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 45: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 46: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 47: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 48: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 49: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 50: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 51: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 52: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
# Generated peptide 53: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRK
# Generated peptide 54: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRKR
# Generated peptide 55: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRKRR
# Generated peptide 56: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRKRRR
# Generated peptide 57: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRKRRRR
# Generated peptide 58: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRKRRRRR
# Generated peptide 59: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRKRRRRRR
# Generated peptide 60: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRKRRRRRRR
# Generated peptide 61: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRKRRRRRRRR
# Generated peptide 62: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRKRRRRRRRRR
# Generated peptide 63: RKRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRKRRRRRRRRRR
# Generated peptide 1: AMAAYRDL
# Generated peptide 2: AMAAYRDLL
# Generated peptide 3: AMAAYRDLLS
# Generated peptide 4: AMAAYRDLLSA
# Generated peptide 5: AMAAYRDLLSAL
# Generated peptide 6: AMAAYRDLLSALL
# Generated peptide 7: AMAAYRDLLSALLR
# Generated peptide 8: AMAAYRDLLSALLRL
# Generated peptide 9: AMAAYRDLLSALLRLL
# Generated peptide 10: AMAAYRDLLSALLRLLA
# Generated peptide 11: AMAAYRDLLSALLRLLAA
# Generated peptide 12: AMAAYRDLLSALLRLLAAL
# Generated peptide 13: AMAAYRDLLSALLRLLAALR
# Generated peptide 14: AMAAYRDLLSALLRLLAALRR
# Generated peptide 15: AMAAYRDLLSALLRLLAALRRL
# Generated peptide 16: AMAAYRDLLSALLRLLAALRRLL
# Generated peptide 17: AMAAYRDLLSALLRLLAALRRLLR
# Generated peptide 18: AMAAYRDLLSALLRLLAALRRLLRR
# Generated peptide 19: AMAAYRDLLSALLRLLAALRRLLRRL
# Generated peptide 20: AMAAYRDLLSALLRLLAALRRLLRRLA
# Generated peptide 21: AMAAYRDLLSALLRLLAALRRLLRRLAR
# Generated peptide 22: AMAAYRDLLSALLRLLAALRRLLRRLARL
# Generated peptide 23: AMAAYRDLLSALLRLLAALRRLLRRLARLR
# Generated peptide 24: AMAAYRDLLSALLRLLAALRRLLRRLARLRA
# Generated peptide 25: AMAAYRDLLSALLRLLAALRRLLRRLARLRAA
# Generated peptide 26: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAY
# Generated peptide 27: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYR
# Generated peptide 28: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRR
# Generated peptide 29: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRL
# Generated peptide 30: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLL
# Generated peptide 31: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLR
# Generated peptide 32: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRL
# Generated peptide 33: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLL
# Generated peptide 34: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLM
# Generated peptide 35: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMA
# Generated peptide 36: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAA
# Generated peptide 37: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAAY
# Generated peptide 38: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAAYR
# Generated peptide 39: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAAYRR
# Generated peptide 40: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAAYRRL
# Generated peptide 41: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAAYRRLL
# Generated peptide 42: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAAYRRLLR
# Generated peptide 43: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAAYRRLLRL
# Generated peptide 44: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAAYRRLLRLL
# Generated peptide 45: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAAYRRLLRLLL
# Generated peptide 46: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAAYRRLLRLLLA
# Generated peptide 47: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAAYRRLLRLLLAL
# Generated peptide 48: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAAYRRLLRLLLALA
# Generated peptide 49: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAAYRRLLRLLLALAA
# Generated peptide 50: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAAYRRLLRLLLALAAA
# Generated peptide 51: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAAYRRLLRLLLALAAAA
# Generated peptide 52: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAAYRRLLRLLLALAAAAA
# Generated peptide 53: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAAYRRLLRLLLALAAAAAA
# Generated peptide 54: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAAYRRLLRLLLALAAAAAAL
# Generated peptide 55: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAAYRRLLRLLLALAAAAAALA
# Generated peptide 56: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAAYRRLLRLLLALAAAAAALAR
# Generated peptide 57: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAAYRRLLRLLLALAAAAAALARA
# Generated peptide 58: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAAYRRLLRLLLALAAAAAALARAL
# Generated peptide 59: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAAYRRLLRLLLALAAAAAALARALR
# Generated peptide 60: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAAYRRLLRLLLALAAAAAALARALRL
# Generated peptide 61: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAAYRRLLRLLLALAAAAAALARALRLL
# Generated peptide 62: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAAYRRLLRLLLALAAAAAALARALRLLA
# Generated peptide 63: AMAAYRDLLSALLRLLAALRRLLRRLARLRAAYRRLLRLLMAAYRRLLRLLLALAAAAAALARALRLLAR
