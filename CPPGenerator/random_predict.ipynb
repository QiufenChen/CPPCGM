# %%
import re
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from transformers import AdamW
import random
import pandas as pd
import numpy as np
import warnings
import torch
from transformers import BertTokenizer, BertLMHeadModel, AdamW, BertForSequenceClassification

# %%
def random_replace_residue(sequence):
    """
    purpose: randomly replace 50% of residues on the target sequence
    :param sequence: target sequence
    :return: new sequence with spaces
    """
    sequence_list = list(sequence)
    replace_indices = random.sample(range(len(sequence_list)), int(0.5 * len(sequence_list)))
    for index in replace_indices:
        sequence_list[index] = random.choice(['A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L', 
                                              'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'W', 'Y'])
    new_sequence = ' '.join(sequence_list)
    return new_sequence


def random_mask_sequence(sequence):
    """
    purpose: mask off 50% of the residues on the target sequence
    :param sequence: target sequence
    :return: new sequence with spaces
    """
    masked_sequence = ''
    mask_positions = []
    for i, aa in enumerate(sequence):
        if random.uniform(0, 1) < 0.5:
            masked_sequence += ' [MASK]'
            mask_positions.append(i)
        else:
            masked_sequence += ' ' + aa
    return masked_sequence


def random_generate_sequence(sequence):
    """
    purpose: randomly generate a sequence as long as the target sequence
    :param sequence: target sequence
    :return: newly generate sequence with spaces
    """
    amino_acids = 'ACDEFGHIKLMNPQRSTVWY'
    new_sequence = ' '.join([random.choice(amino_acids) for _ in range(len(sequence))])
    return new_sequence


class Generator(nn.Module):
    """ Define Generator """
    def __init__(self):
        super().__init__()
        self.model = BertLMHeadModel.from_pretrained(model_name, return_dict=False).cuda()
    
    def forward(self, input_ids, attention_mask):
        output = self.model(input_ids=input_ids, attention_mask=attention_mask)
        output_ids = torch.argmax(output[0], -1)
        return output_ids, output


class SequenceDataset(Dataset):
    """Create SequenceDataset Loader"""
    def __init__(self, sequences):
        self.sequences = sequences

    def __len__(self):
        return len(self.sequences)

    def __getitem__(self, index):
        real_seq = self.sequences[index]
        fake_seq = random_generate_sequence(real_seq)

        real_seq = " ".join("".join(real_seq.split()))
        real_seq = re.sub(r"[UZOB]", "X", real_seq)
        real_seq_ids = tokenizer(real_seq, truncation=True, padding='max_length', max_length=70)
        real_sample = {key: torch.tensor(val) for key, val in real_seq_ids .items()}
        real_data = real_sample['input_ids']
        real_attention_mask = (real_sample['attention_mask'])

        fake_seq = re.sub(r"[UZOB]", "X", fake_seq)
        fake_seq_ids = tokenizer(fake_seq, truncation=True, padding='max_length', max_length=70)
        fake_sample = {key: torch.tensor(val) for key, val in fake_seq_ids.items()}
        fake_data = fake_sample['input_ids']
        fake_attention_mask = (fake_sample['attention_mask'])
        return (real_data, fake_data, fake_attention_mask)

# %%
model_name = "../Rostlab/prot_bert_bfd"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
tokenizer = BertTokenizer.from_pretrained(model_name)

# Load dataset and create Dataloader
file = '../dataset/CPPCase-2.csv'
seqs = [item for item in pd.read_csv(file)['Sequence'].values]
batch_size = 9
dataset = SequenceDataset(seqs)
dataloader = DataLoader(dataset=dataset, batch_size=batch_size, shuffle=False)

model = Generator()
model.load_state_dict(torch.load('/home/qfchen/CPPCGM/CPPGenerator/model/random_generator.pt'))

model.eval()
generated_sequences = []
with torch.no_grad(): 
    for i, data in enumerate(dataloader):
        gene_data, gene_logits = model(data[1].to(device), data[2].to(device))
        decoded_seqs = tokenizer.batch_decode(gene_data, skip_special_tokens=True)
        generated_sequences.extend(decoded_seqs)
# Out:
# If you want to use `BertLMHeadModel` as a standalone, add `is_decoder=True.`
# /tmp/ipykernel_597744/221736569.py:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('/home/qfchen/CPPCGM/CPPGenerator/model/random_generator.pt'))

# %%
for i, seq in enumerate(generated_sequences):
    print(f"Generated peptide {i+1}: {seq.replace(' ', '')}")
# Out:
# Generated peptide 1: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDPVESSESSDDDDDDDDDPVDSDSSDDDS
# Generated peptide 2: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWWTWWTWWWGGGGGGGGWWGGGGWWWTWM
# Generated peptide 3: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQKPGQKGQKGGGGGGGGQKGGQGGGKGG
# Generated peptide 4: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGADKAYPAYAAAAAAAAGAAAAAAAAAAA
# Generated peptide 5: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGGGGGEKKEGGGXGGGGGGGGGGKKGGKG

# %%
generated_sequences = [peptide.replace(' ', '') for peptide in generated_sequences]
start_len = 8

all_sequences = []
for peptide in generated_sequences:
    item = 0
    for length in range(start_len, len(peptide) + 1): 
        sequence = peptide[:length]
        if sequence not in seqs:
            all_sequences.append(sequence)
        print(f"Generated peptide {item + 1}: {sequence}")
        item += 1


df = pd.DataFrame(all_sequences, columns=["Peptide"])
df.to_csv('results/random_generated_peptides_1.csv', index=False)
# Out:
# Generated peptide 1: DDDPVESS
# Generated peptide 2: DDDPVESSS
# Generated peptide 3: DDDPVESSSS
# Generated peptide 4: DDDPVESSSSS
# Generated peptide 5: DDDPVESSSSSD
# Generated peptide 6: DDDPVESSSSSDS
# Generated peptide 7: DDDPVESSSSSDSD
# Generated peptide 8: DDDPVESSSSSDSDP
# Generated peptide 9: DDDPVESSSSSDSDPV
# Generated peptide 10: DDDPVESSSSSDSDPVE
# Generated peptide 11: DDDPVESSSSSDSDPVEP
# Generated peptide 12: DDDPVESSSSSDSDPVEPV
# Generated peptide 13: DDDPVESSSSSDSDPVEPVE
# Generated peptide 14: DDDPVESSSSSDSDPVEPVES
# Generated peptide 15: DDDPVESSSSSDSDPVEPVESD
# Generated peptide 16: DDDPVESSSSSDSDPVEPVESDS
# Generated peptide 17: DDDPVESSSSSDSDPVEPVESDSS
# Generated peptide 18: DDDPVESSSSSDSDPVEPVESDSSS
# Generated peptide 19: DDDPVESSSSSDSDPVEPVESDSSSV
# Generated peptide 20: DDDPVESSSSSDSDPVEPVESDSSSVD
# Generated peptide 21: DDDPVESSSSSDSDPVEPVESDSSSVDS
# Generated peptide 22: DDDPVESSSSSDSDPVEPVESDSSSVDSV
# Generated peptide 23: DDDPVESSSSSDSDPVEPVESDSSSVDSVE
# Generated peptide 24: DDDPVESSSSSDSDPVEPVESDSSSVDSVED
# Generated peptide 25: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDP
# Generated peptide 26: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPV
# Generated peptide 27: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVE
# Generated peptide 28: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVES
# Generated peptide 29: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESD
# Generated peptide 30: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDS
# Generated peptide 31: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSS
# Generated peptide 32: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSD
# Generated peptide 33: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDV
# Generated peptide 34: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVD
# Generated peptide 35: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDD
# Generated peptide 36: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDP
# Generated peptide 37: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDPV
# Generated peptide 38: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDPVE
# Generated peptide 39: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDPVES
# Generated peptide 40: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDPVESS
# Generated peptide 41: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDPVESSE
# Generated peptide 42: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDPVESSES
# Generated peptide 43: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDPVESSESS
# Generated peptide 44: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDPVESSESSD
# Generated peptide 45: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDPVESSESSDD
# Generated peptide 46: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDPVESSESSDDD
# Generated peptide 47: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDPVESSESSDDDD
# Generated peptide 48: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDPVESSESSDDDDD
# Generated peptide 49: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDPVESSESSDDDDDD
# Generated peptide 50: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDPVESSESSDDDDDDD
# Generated peptide 51: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDPVESSESSDDDDDDDD
# Generated peptide 52: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDPVESSESSDDDDDDDDD
# Generated peptide 53: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDPVESSESSDDDDDDDDDP
# Generated peptide 54: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDPVESSESSDDDDDDDDDPV
# Generated peptide 55: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDPVESSESSDDDDDDDDDPVD
# Generated peptide 56: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDPVESSESSDDDDDDDDDPVDS
# Generated peptide 57: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDPVESSESSDDDDDDDDDPVDSD
# Generated peptide 58: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDPVESSESSDDDDDDDDDPVDSDS
# Generated peptide 59: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDPVESSESSDDDDDDDDDPVDSDSS
# Generated peptide 60: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDPVESSESSDDDDDDDDDPVDSDSSD
# Generated peptide 61: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDPVESSESSDDDDDDDDDPVDSDSSDD
# Generated peptide 62: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDPVESSESSDDDDDDDDDPVDSDSSDDD
# Generated peptide 63: DDDPVESSSSSDSDPVEPVESDSSSVDSVEDPVESDSSDVDDPVESSESSDDDDDDDDDPVDSDSSDDDS
# Generated peptide 1: GDWWTWMW
# Generated peptide 2: GDWWTWMWW
# Generated peptide 3: GDWWTWMWWW
# Generated peptide 4: GDWWTWMWWWM
# Generated peptide 5: GDWWTWMWWWMW
# Generated peptide 6: GDWWTWMWWWMWW
# Generated peptide 7: GDWWTWMWWWMWWW
# Generated peptide 8: GDWWTWMWWWMWWWW
# Generated peptide 9: GDWWTWMWWWMWWWWT
# Generated peptide 10: GDWWTWMWWWMWWWWTW
# Generated peptide 11: GDWWTWMWWWMWWWWTWW
# Generated peptide 12: GDWWTWMWWWMWWWWTWWW
# Generated peptide 13: GDWWTWMWWWMWWWWTWWWW
# Generated peptide 14: GDWWTWMWWWMWWWWTWWWWW
# Generated peptide 15: GDWWTWMWWWMWWWWTWWWWWW
# Generated peptide 16: GDWWTWMWWWMWWWWTWWWWWWW
# Generated peptide 17: GDWWTWMWWWMWWWWTWWWWWWWW
# Generated peptide 18: GDWWTWMWWWMWWWWTWWWWWWWWM
# Generated peptide 19: GDWWTWMWWWMWWWWTWWWWWWWWMG
# Generated peptide 20: GDWWTWMWWWMWWWWTWWWWWWWWMGW
# Generated peptide 21: GDWWTWMWWWMWWWWTWWWWWWWWMGWW
# Generated peptide 22: GDWWTWMWWWMWWWWTWWWWWWWWMGWWW
# Generated peptide 23: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWW
# Generated peptide 24: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWW
# Generated peptide 25: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWW
# Generated peptide 26: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWT
# Generated peptide 27: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTW
# Generated peptide 28: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWM
# Generated peptide 29: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMW
# Generated peptide 30: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWG
# Generated peptide 31: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGW
# Generated peptide 32: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWW
# Generated peptide 33: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWT
# Generated peptide 34: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTW
# Generated peptide 35: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWW
# Generated peptide 36: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWW
# Generated peptide 37: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWWT
# Generated peptide 38: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWWTW
# Generated peptide 39: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWWTWW
# Generated peptide 40: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWWTWWT
# Generated peptide 41: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWWTWWTW
# Generated peptide 42: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWWTWWTWW
# Generated peptide 43: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWWTWWTWWW
# Generated peptide 44: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWWTWWTWWWG
# Generated peptide 45: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWWTWWTWWWGG
# Generated peptide 46: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWWTWWTWWWGGG
# Generated peptide 47: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWWTWWTWWWGGGG
# Generated peptide 48: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWWTWWTWWWGGGGG
# Generated peptide 49: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWWTWWTWWWGGGGGG
# Generated peptide 50: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWWTWWTWWWGGGGGGG
# Generated peptide 51: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWWTWWTWWWGGGGGGGG
# Generated peptide 52: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWWTWWTWWWGGGGGGGGW
# Generated peptide 53: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWWTWWTWWWGGGGGGGGWW
# Generated peptide 54: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWWTWWTWWWGGGGGGGGWWG
# Generated peptide 55: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWWTWWTWWWGGGGGGGGWWGG
# Generated peptide 56: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWWTWWTWWWGGGGGGGGWWGGG
# Generated peptide 57: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWWTWWTWWWGGGGGGGGWWGGGG
# Generated peptide 58: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWWTWWTWWWGGGGGGGGWWGGGGW
# Generated peptide 59: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWWTWWTWWWGGGGGGGGWWGGGGWW
# Generated peptide 60: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWWTWWTWWWGGGGGGGGWWGGGGWWW
# Generated peptide 61: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWWTWWTWWWGGGGGGGGWWGGGGWWWT
# Generated peptide 62: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWWTWWTWWWGGGGGGGGWWGGGGWWWTW
# Generated peptide 63: GDWWTWMWWWMWWWWTWWWWWWWWMGWWWWWWTWMWGWWTWWWTWWTWWWGGGGGGGGWWGGGGWWWTWM
# Generated peptide 1: GPGQKPGQ
# Generated peptide 2: GPGQKPGQK
# Generated peptide 3: GPGQKPGQKG
# Generated peptide 4: GPGQKPGQKGQ
# Generated peptide 5: GPGQKPGQKGQQ
# Generated peptide 6: GPGQKPGQKGQQK
# Generated peptide 7: GPGQKPGQKGQQKG
# Generated peptide 8: GPGQKPGQKGQQKGQ
# Generated peptide 9: GPGQKPGQKGQQKGQK
# Generated peptide 10: GPGQKPGQKGQQKGQKP
# Generated peptide 11: GPGQKPGQKGQQKGQKPQ
# Generated peptide 12: GPGQKPGQKGQQKGQKPQK
# Generated peptide 13: GPGQKPGQKGQQKGQKPQKP
# Generated peptide 14: GPGQKPGQKGQQKGQKPQKPG
# Generated peptide 15: GPGQKPGQKGQQKGQKPQKPGQ
# Generated peptide 16: GPGQKPGQKGQQKGQKPQKPGQK
# Generated peptide 17: GPGQKPGQKGQQKGQKPQKPGQKG
# Generated peptide 18: GPGQKPGQKGQQKGQKPQKPGQKGG
# Generated peptide 19: GPGQKPGQKGQQKGQKPQKPGQKGGK
# Generated peptide 20: GPGQKPGQKGQQKGQKPQKPGQKGGKP
# Generated peptide 21: GPGQKPGQKGQQKGQKPQKPGQKGGKPG
# Generated peptide 22: GPGQKPGQKGQQKGQKPQKPGQKGGKPGK
# Generated peptide 23: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKP
# Generated peptide 24: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPG
# Generated peptide 25: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQ
# Generated peptide 26: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQK
# Generated peptide 27: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKP
# Generated peptide 28: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPG
# Generated peptide 29: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQ
# Generated peptide 30: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQK
# Generated peptide 31: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKP
# Generated peptide 32: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPP
# Generated peptide 33: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPK
# Generated peptide 34: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKM
# Generated peptide 35: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMG
# Generated peptide 36: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQ
# Generated peptide 37: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQK
# Generated peptide 38: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQKP
# Generated peptide 39: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQKPG
# Generated peptide 40: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQKPGQ
# Generated peptide 41: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQKPGQK
# Generated peptide 42: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQKPGQKG
# Generated peptide 43: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQKPGQKGQ
# Generated peptide 44: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQKPGQKGQK
# Generated peptide 45: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQKPGQKGQKG
# Generated peptide 46: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQKPGQKGQKGG
# Generated peptide 47: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQKPGQKGQKGGG
# Generated peptide 48: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQKPGQKGQKGGGG
# Generated peptide 49: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQKPGQKGQKGGGGG
# Generated peptide 50: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQKPGQKGQKGGGGGG
# Generated peptide 51: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQKPGQKGQKGGGGGGG
# Generated peptide 52: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQKPGQKGQKGGGGGGGG
# Generated peptide 53: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQKPGQKGQKGGGGGGGGQ
# Generated peptide 54: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQKPGQKGQKGGGGGGGGQK
# Generated peptide 55: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQKPGQKGQKGGGGGGGGQKG
# Generated peptide 56: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQKPGQKGQKGGGGGGGGQKGG
# Generated peptide 57: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQKPGQKGQKGGGGGGGGQKGGQ
# Generated peptide 58: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQKPGQKGQKGGGGGGGGQKGGQG
# Generated peptide 59: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQKPGQKGQKGGGGGGGGQKGGQGG
# Generated peptide 60: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQKPGQKGQKGGGGGGGGQKGGQGGG
# Generated peptide 61: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQKPGQKGQKGGGGGGGGQKGGQGGGK
# Generated peptide 62: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQKPGQKGQKGGGGGGGGQKGGQGGGKG
# Generated peptide 63: GPGQKPGQKGQQKGQKPQKPGQKGGKPGKPGQKPGQKPPKMGQKPGQKGQKGGGGGGGGQKGGQGGGKGG
# Generated peptide 1: APGADKAY
# Generated peptide 2: APGADKAYA
# Generated peptide 3: APGADKAYAA
# Generated peptide 4: APGADKAYAAA
# Generated peptide 5: APGADKAYAAAY
# Generated peptide 6: APGADKAYAAAYP
# Generated peptide 7: APGADKAYAAAYPA
# Generated peptide 8: APGADKAYAAAYPAA
# Generated peptide 9: APGADKAYAAAYPAAD
# Generated peptide 10: APGADKAYAAAYPAADK
# Generated peptide 11: APGADKAYAAAYPAADKA
# Generated peptide 12: APGADKAYAAAYPAADKAD
# Generated peptide 13: APGADKAYAAAYPAADKADK
# Generated peptide 14: APGADKAYAAAYPAADKADKA
# Generated peptide 15: APGADKAYAAAYPAADKADKAA
# Generated peptide 16: APGADKAYAAAYPAADKADKAAA
# Generated peptide 17: APGADKAYAAAYPAADKADKAAAA
# Generated peptide 18: APGADKAYAAAYPAADKADKAAAAA
# Generated peptide 19: APGADKAYAAAYPAADKADKAAAAAA
# Generated peptide 20: APGADKAYAAAYPAADKADKAAAAAAK
# Generated peptide 21: APGADKAYAAAYPAADKADKAAAAAAKA
# Generated peptide 22: APGADKAYAAAYPAADKADKAAAAAAKAA
# Generated peptide 23: APGADKAYAAAYPAADKADKAAAAAAKAAP
# Generated peptide 24: APGADKAYAAAYPAADKADKAAAAAAKAAPG
# Generated peptide 25: APGADKAYAAAYPAADKADKAAAAAAKAAPGA
# Generated peptide 26: APGADKAYAAAYPAADKADKAAAAAAKAAPGAD
# Generated peptide 27: APGADKAYAAAYPAADKADKAAAAAAKAAPGADK
# Generated peptide 28: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKA
# Generated peptide 29: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAY
# Generated peptide 30: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYP
# Generated peptide 31: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPA
# Generated peptide 32: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAA
# Generated peptide 33: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAAD
# Generated peptide 34: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADP
# Generated peptide 35: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPG
# Generated peptide 36: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGA
# Generated peptide 37: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGAD
# Generated peptide 38: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGADK
# Generated peptide 39: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGADKA
# Generated peptide 40: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGADKAY
# Generated peptide 41: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGADKAYP
# Generated peptide 42: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGADKAYPA
# Generated peptide 43: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGADKAYPAY
# Generated peptide 44: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGADKAYPAYA
# Generated peptide 45: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGADKAYPAYAA
# Generated peptide 46: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGADKAYPAYAAA
# Generated peptide 47: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGADKAYPAYAAAA
# Generated peptide 48: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGADKAYPAYAAAAA
# Generated peptide 49: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGADKAYPAYAAAAAA
# Generated peptide 50: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGADKAYPAYAAAAAAA
# Generated peptide 51: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGADKAYPAYAAAAAAAA
# Generated peptide 52: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGADKAYPAYAAAAAAAAG
# Generated peptide 53: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGADKAYPAYAAAAAAAAGA
# Generated peptide 54: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGADKAYPAYAAAAAAAAGAA
# Generated peptide 55: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGADKAYPAYAAAAAAAAGAAA
# Generated peptide 56: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGADKAYPAYAAAAAAAAGAAAA
# Generated peptide 57: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGADKAYPAYAAAAAAAAGAAAAA
# Generated peptide 58: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGADKAYPAYAAAAAAAAGAAAAAA
# Generated peptide 59: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGADKAYPAYAAAAAAAAGAAAAAAA
# Generated peptide 60: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGADKAYPAYAAAAAAAAGAAAAAAAA
# Generated peptide 61: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGADKAYPAYAAAAAAAAGAAAAAAAAA
# Generated peptide 62: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGADKAYPAYAAAAAAAAGAAAAAAAAAA
# Generated peptide 63: APGADKAYAAAYPAADKADKAAAAAAKAAPGADKAYPAADPGADKAYPAYAAAAAAAAGAAAAAAAAAAA
# Generated peptide 1: GYGGGGGE
# Generated peptide 2: GYGGGGGEK
# Generated peptide 3: GYGGGGGEKK
# Generated peptide 4: GYGGGGGEKKG
# Generated peptide 5: GYGGGGGEKKGG
# Generated peptide 6: GYGGGGGEKKGGG
# Generated peptide 7: GYGGGGGEKKGGGK
# Generated peptide 8: GYGGGGGEKKGGGKG
# Generated peptide 9: GYGGGGGEKKGGGKGG
# Generated peptide 10: GYGGGGGEKKGGGKGGG
# Generated peptide 11: GYGGGGGEKKGGGKGGGG
# Generated peptide 12: GYGGGGGEKKGGGKGGGGG
# Generated peptide 13: GYGGGGGEKKGGGKGGGGGG
# Generated peptide 14: GYGGGGGEKKGGGKGGGGGGG
# Generated peptide 15: GYGGGGGEKKGGGKGGGGGGGE
# Generated peptide 16: GYGGGGGEKKGGGKGGGGGGGEG
# Generated peptide 17: GYGGGGGEKKGGGKGGGGGGGEGK
# Generated peptide 18: GYGGGGGEKKGGGKGGGGGGGEGKG
# Generated peptide 19: GYGGGGGEKKGGGKGGGGGGGEGKGG
# Generated peptide 20: GYGGGGGEKKGGGKGGGGGGGEGKGGK
# Generated peptide 21: GYGGGGGEKKGGGKGGGGGGGEGKGGKG
# Generated peptide 22: GYGGGGGEKKGGGKGGGGGGGEGKGGKGG
# Generated peptide 23: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGG
# Generated peptide 24: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGG
# Generated peptide 25: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGG
# Generated peptide 26: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGG
# Generated peptide 27: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGG
# Generated peptide 28: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGG
# Generated peptide 29: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGE
# Generated peptide 30: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEK
# Generated peptide 31: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKK
# Generated peptide 32: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKG
# Generated peptide 33: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGG
# Generated peptide 34: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGY
# Generated peptide 35: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYG
# Generated peptide 36: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGG
# Generated peptide 37: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGGG
# Generated peptide 38: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGGGG
# Generated peptide 39: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGGGGG
# Generated peptide 40: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGGGGGE
# Generated peptide 41: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGGGGGEK
# Generated peptide 42: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGGGGGEKK
# Generated peptide 43: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGGGGGEKKE
# Generated peptide 44: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGGGGGEKKEG
# Generated peptide 45: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGGGGGEKKEGG
# Generated peptide 46: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGGGGGEKKEGGG
# Generated peptide 47: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGGGGGEKKEGGGX
# Generated peptide 48: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGGGGGEKKEGGGXG
# Generated peptide 49: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGGGGGEKKEGGGXGG
# Generated peptide 50: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGGGGGEKKEGGGXGGG
# Generated peptide 51: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGGGGGEKKEGGGXGGGG
# Generated peptide 52: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGGGGGEKKEGGGXGGGGG
# Generated peptide 53: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGGGGGEKKEGGGXGGGGGG
# Generated peptide 54: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGGGGGEKKEGGGXGGGGGGG
# Generated peptide 55: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGGGGGEKKEGGGXGGGGGGGG
# Generated peptide 56: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGGGGGEKKEGGGXGGGGGGGGG
# Generated peptide 57: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGGGGGEKKEGGGXGGGGGGGGGG
# Generated peptide 58: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGGGGGEKKEGGGXGGGGGGGGGGK
# Generated peptide 59: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGGGGGEKKEGGGXGGGGGGGGGGKK
# Generated peptide 60: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGGGGGEKKEGGGXGGGGGGGGGGKKG
# Generated peptide 61: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGGGGGEKKEGGGXGGGGGGGGGGKKGG
# Generated peptide 62: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGGGGGEKKEGGGXGGGGGGGGGGKKGGK
# Generated peptide 63: GYGGGGGEKKGGGKGGGGGGGEGKGGKGGGGGGGGEKKGGYGGGGGEKKEGGGXGGGGGGGGGGKKGGKG
